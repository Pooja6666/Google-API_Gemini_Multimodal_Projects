# %%
import google.generativeai as genai
import os 
from gemini_api_key import google_key

# %%
os.environ["Ramyaa"] = google_key

Ramyaa = google_key

# %%
model = genai.configure(api_key = Ramyaa)

# %%
for i in genai.list_models():
    print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001-tuning
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = genai.GenerativeModel(model_name = 'models/gemini-1.5-pro',system_instruction = "You are helpful as AI assistant.User have error when loading an image.You are helpful as User friendly")

user_prompt = "SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 12-13: truncated \UXXXXXXXX escape"                                                                   ^

    
response = model.generate_content(user_prompt)

print(response.text)
# Out:
#   Cell In[9], line 3
#     user_prompt = "SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 12-13: truncated \UXXXXXXXX escape"                                                                   ^
#                                                                                                                                                                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 99-100: truncated \UXXXXXXXX escape

# %%
#!pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open(r"C:\Users\DELL\OneDrive\Pictures\chatak bird.jpg")


plt.imshow(img)

# %%
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest")

response = model.generate_content(img)

print(response.text)
# Out:
# The image shows two birds, likely Red-whiskered Bulbuls, perched on a branch. They have brown bodies, black heads with red patches beneath the eyes, and long tails. The birds appear to be interacting with each other, perhaps singing or calling.  The background is a blur of green foliage, suggesting a natural habitat.

# %% [markdown]
# ## User Prompt

# %%
User_prompt ="In the given image right side bird what doing with left side bird ?"

response = model.generate_content([img,User_prompt])

print(response.text)
# Out:
# The bird on the right is interacting with the bird on the left. It's difficult to say definitively what's happening without more context or video footage. Here are some possibilities:
#
# * **Courtship/Mating Ritual:** The bird on the right could be engaging in a courtship display, trying to attract the attention of the bird on the left.
# * **Communication/Territorial Dispute:** The birds could be communicating with each other, perhaps asserting dominance or defending their territory.
# * **Playful Interaction:** While less likely, it's possible the birds are engaging in playful behavior.
#
# Let me know if you have any other questions!
